# %%
import kagglehub
import pandas as pd

# Download latest version
path = kagglehub.dataset_download("olistbr/brazilian-ecommerce")

#print("Path to dataset files:", path)

# %%
df_customers = pd.read_csv("C:/Users/lugul/Desktop/SCTEC_site/Trilha-Dados/kaggle/olist_customers_dataset.csv", dtype={"customer_zip_code_prefix": str})


df_customers.info()
df_customers.describe()
df_customers.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  str
#  1   customer_unique_id        99441 non-null  str
#  2   customer_zip_code_prefix  99441 non-null  str
#  3   customer_city             99441 non-null  str
#  4   customer_state            99441 non-null  str
# dtypes: str(5)
# memory usage: 3.8 MB
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
# ...

# %%
df_orders = pd.read_csv("C:/Users/lugul/Desktop/SCTEC_site/Trilha-Dados/kaggle/olist_orders_dataset.csv")
df_orders.info()
df_orders["order_status"].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  str
#  4   order_approved_at              99281 non-null  str
#  5   order_delivered_carrier_date   97658 non-null  str
#  6   order_delivered_customer_date  96476 non-null  str
#  7   order_estimated_delivery_date  99441 non-null  str
# dtypes: str(8)
# memory usage: 6.1 MB
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
nulos_pct = df_reviews.isnull().mean() * 100
nulos_pct
# Out:
# review_id                   0.000000
# order_id                    0.000000
# review_score                0.000000
# review_comment_title       88.341530
# review_comment_message     58.702532
# review_creation_date        0.000000
# review_answer_timestamp     0.000000
# dtype: float64

# %%
df_orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  str
#  4   order_approved_at              99281 non-null  str
#  5   order_delivered_carrier_date   97658 non-null  str
#  6   order_delivered_customer_date  96476 non-null  str
#  7   order_estimated_delivery_date  99441 non-null  str
# dtypes: str(8)
# memory usage: 6.1 MB

# %%
total_duplicadas = df_orders.duplicated().sum()
total_duplicadas
# Out:
# np.int64(0)

# %%
total_dupl_id_order_id = df_orders.duplicated(subset="order_id").sum()
total_dupl_id_order_id
# Out:
# np.int64(0)

# %%
df_reviews = pd.read_csv("C:/Users/lugul/Desktop/SCTEC_site/Trilha-Dados/kaggle/olist_order_reviews_dataset.csv")
df_reviews.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  str
#  1   order_id                 99224 non-null  str
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  str
#  4   review_comment_message   40977 non-null  str
#  5   review_creation_date     99224 non-null  str
#  6   review_answer_timestamp  99224 non-null  str
# dtypes: int64(1), str(6)
# memory usage: 5.3 MB

# %%
df_reviews = df_reviews.drop(columns=["review_comment_title","review_comment_message","review_creation_date", "review_answer_timestamp"])
df_reviews.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   review_id     99224 non-null  str
#  1   order_id      99224 non-null  str
#  2   review_score  99224 non-null  int64
# dtypes: int64(1), str(2)
# memory usage: 2.3 MB

# %%
df_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
df_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#   customer_zip_code_prefix          customer_city customer_state
# 0                    14409                 franca             SP
# 1                    09790  sao bernardo do campo             SP
# 2                    01151              sao paulo             SP
# 3                    08775        mogi das cruzes             SP
# 4                    13056               campinas             SP

# %%
df_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score
# 0             4
# 1             5
# 2             5
# 3             5
# 4             5

# %%
df_items = pd.read_csv("C:/Users/lugul/Desktop/SCTEC_site/Trilha-Dados/kaggle/olist_order_items_dataset.csv")
df_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
df_main = df_orders.merge(df_customers, on="customer_id", how="inner")
df_main.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  str
#  4   order_approved_at              99281 non-null  str
#  5   order_delivered_carrier_date   97658 non-null  str
#  6   order_delivered_customer_date  96476 non-null  str
#  7   order_estimated_delivery_date  99441 non-null  str
#  8   customer_unique_id             99441 non-null  str
#  9   customer_zip_code_prefix       99441 non-null  str
#  10  customer_city                  99441 non-null  str
#  11  customer_state                 99441 non-null  str
# dtypes: str(12)
# memory usage: 9.1 MB

# %%
df_main = df_main.merge(df_items, on="order_id", how="inner")
df_main.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112650 non-null  str
#  1   customer_id                    112650 non-null  str
#  2   order_status                   112650 non-null  str
#  3   order_purchase_timestamp       112650 non-null  str
#  4   order_approved_at              112635 non-null  str
#  5   order_delivered_carrier_date   111456 non-null  str
#  6   order_delivered_customer_date  110196 non-null  str
#  7   order_estimated_delivery_date  112650 non-null  str
#  8   customer_unique_id             112650 non-null  str
#  9   customer_zip_code_prefix       112650 non-null  str
#  10  customer_city                  112650 non-null  str
#  11  customer_state                 112650 non-null  str
#  12  order_item_id                  112650 non-null  int64
# ...

# %%
df_main = df_main.merge(df_reviews, on="order_id", how="left")
df_main.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 113314 entries, 0 to 113313
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       113314 non-null  str
#  1   customer_id                    113314 non-null  str
#  2   order_status                   113314 non-null  str
#  3   order_purchase_timestamp       113314 non-null  str
#  4   order_approved_at              113299 non-null  str
#  5   order_delivered_carrier_date   112111 non-null  str
#  6   order_delivered_customer_date  110839 non-null  str
#  7   order_estimated_delivery_date  113314 non-null  str
#  8   customer_unique_id             113314 non-null  str
#  9   customer_zip_code_prefix       113314 non-null  str
#  10  customer_city                  113314 non-null  str
#  11  customer_state                 113314 non-null  str
#  12  order_item_id                  113314 non-null  int64
# ...

# %%
df_main = df_main.drop(columns=["customer_id"])
df_main.head()
# Out:
#                            order_id order_status order_purchase_timestamp  \
# 0  e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# 1  53cdb2fc8bc7dce0b6741e2150273451    delivered      2018-07-24 20:41:37
# 2  47770eb9100c2d0c44946d9cf07ec65d    delivered      2018-08-08 08:38:49
# 3  949d5b44dbf5de918fe9c16f97b45f8a    delivered      2017-11-18 19:28:06
# 4  ad21c59c0840e6cb83a9ceb5573f8159    delivered      2018-02-13 21:18:39
#
#      order_approved_at order_delivered_carrier_date  \
# 0  2017-10-02 11:07:15          2017-10-04 19:55:00
# 1  2018-07-26 03:24:27          2018-07-26 14:31:00
# 2  2018-08-08 08:55:23          2018-08-08 13:50:00
# 3  2017-11-18 19:45:59          2017-11-22 13:39:59
# 4  2018-02-13 22:20:29          2018-02-14 19:46:34
#
#   order_delivered_customer_date order_estimated_delivery_date  \
# 0           2017-10-10 21:25:13           2017-10-18 00:00:00
# 1           2018-08-07 15:27:45           2018-08-13 00:00:00
# ...

# %%
df_main = df_main[df_main["order_status"] == "delivered"]
df_main.info()
df_main.head()
df_main.tail()
# Out:
# <class 'pandas.DataFrame'>
# Index: 110840 entries, 0 to 113313
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       110840 non-null  str
#  1   order_status                   110840 non-null  str
#  2   order_purchase_timestamp       110840 non-null  str
#  3   order_approved_at              110825 non-null  str
#  4   order_delivered_carrier_date   110838 non-null  str
#  5   order_delivered_customer_date  110832 non-null  str
#  6   order_estimated_delivery_date  110840 non-null  str
#  7   customer_unique_id             110840 non-null  str
#  8   customer_zip_code_prefix       110840 non-null  str
#  9   customer_city                  110840 non-null  str
#  10  customer_state                 110840 non-null  str
#  11  order_item_id                  110840 non-null  int64
#  12  product_id                     110840 non-null  str
# ...

# %%
df_main["order_status"].value_counts()
# Out:
# order_status
# delivered    110840
# Name: count, dtype: int64

# %%
df_main["order_purchase_timestamp"] = pd.to_datetime(df_main["order_purchase_timestamp"], format="%Y-%m-%d %H:%M:%S")
df_main["order_purchase_timestamp"]
# Out:
# 0        2017-10-02 10:56:33
# 1        2018-07-24 20:41:37
# 2        2018-08-08 08:38:49
# 3        2017-11-18 19:28:06
# 4        2018-02-13 21:18:39
#                  ...
# 113309   2018-02-06 12:58:58
# 113310   2017-08-27 14:46:43
# 113311   2018-01-08 21:28:27
# 113312   2018-01-08 21:28:27
# 113313   2018-03-08 20:57:30
# Name: order_purchase_timestamp, Length: 110840, dtype: datetime64[us]

# %%
df_main["ano_mes"] = df_main["order_purchase_timestamp"].dt.to_period("M"). astype(str)
df_main["ano_mes"]
# Out:
# 0         2017-10
# 1         2018-07
# 2         2018-08
# 3         2017-11
# 4         2018-02
#            ...
# 113309    2018-02
# 113310    2017-08
# 113311    2018-01
# 113312    2018-01
# 113313    2018-03
# Name: ano_mes, Length: 110840, dtype: str

# %%
pedidos_por_mes = df_main.groupby("ano_mes")["order_id"].count().reset_index()
pedidos_por_mes
# Out:
#     ano_mes  order_id
# 0   2016-09         3
# 1   2016-10       317
# 2   2016-12         1
# 3   2017-01       924
# 4   2017-02      1869
# 5   2017-03      2917
# 6   2017-04      2577
# 7   2017-05      4048
# 8   2017-06      3524
# 9   2017-07      4460
# 10  2017-08      4851
# 11  2017-09      4771
# 12  2017-10      5256
# 13  2017-11      8537
# 14  2017-12      6214
# 15  2018-01      8088
# 16  2018-02      7617
# 17  2018-03      8064
# 18  2018-04      7838
# 19  2018-05      7819
# 20  2018-06      7016
# 21  2018-07      6985
# 22  2018-08      7144

# %%
import matplotlib.pyplot as plt
plt.plot(pedidos_por_mes["ano_mes"], pedidos_por_mes["order_id"])
plt.xlabel("Mês")
plt.ylabel("Quantidade de pedidos")
plt.xticks(rotation=45)
plt.title("Têndencia de Pedidos ao Longo do Tempo")
# Out:
# Text(0.5, 1.0, 'Têndencia de Pedidos ao Longo do Tempo')

# %%
df_main["order_delivered_customer_date"] = pd.to_datetime(
    df_main["order_delivered_customer_date"], format= "%Y-%m-%d %H:%M:%S"
)
df_main["order_delivered_customer_date"]
# Out:
# 0        2017-10-10 21:25:13
# 1        2018-08-07 15:27:45
# 2        2018-08-17 18:06:29
# 3        2017-12-02 00:28:42
# 4        2018-02-16 18:17:02
#                  ...
# 113309   2018-02-28 17:37:56
# 113310   2017-09-21 11:24:17
# 113311   2018-01-25 23:32:54
# 113312   2018-01-25 23:32:54
# 113313   2018-03-16 13:08:30
# Name: order_delivered_customer_date, Length: 110840, dtype: datetime64[us]

# %%
df_main["dias_espera"] = (df_main["order_delivered_customer_date"] - df_main["order_purchase_timestamp"]).dt.days
df_main["dias_espera"]
# Out:
# 0          8.0
# 1         13.0
# 2          9.0
# 3         13.0
# 4          2.0
#           ...
# 113309    22.0
# 113310    24.0
# 113311    17.0
# 113312    17.0
# 113313     7.0
# Name: dias_espera, Length: 110840, dtype: float64

# %%
bugs_dias = df_main[df_main["dias_espera"]<0]
print(f"Viagens no tempo: {len(bugs_dias)}")
# Out:
# Viagens no tempo: 0

# %%
bugs_extremos = df_main[df_main["dias_espera"]>150]
print(f"Atrasos extremos: {len(bugs_extremos)}")
# Out:
# Atrasos extremos: 27

# %%
import seaborn as sns

corr = df_main[["dias_espera", "review_score"]].corr()

sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# PERGUNTAS A SEREM RESPONDIDAS
#
# 1. Qual é a tendencia de volume de pedidos da Olist ao longo do tempo?
# 2. COmo o custo médio do frete varia geograficamente pelo Brasil?
# 3. Qual é o impacto real e quantificável de demora na entrega sobre a nota de satisfação do cliente?
# 4. Quais categorias de produtos do catálog mais puxam a satisfação para baixo e sofrem com a complexidade logística?
